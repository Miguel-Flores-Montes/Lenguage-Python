# %% [markdown]
# <a href="https://colab.research.google.com/github/Miguel-Flores-Montes/Lenguaje-Python/blob/master/expo_en_tf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
capa = tf.keras.layers.Dense(units=1, input_shape=[1])
modelo = tf.keras.Sequential([capa])

# %%
celsius =np.array([-40,-10,0,8,15,22,38], dtype=float)
fahrenheit = np.array([-40,14,32,46,59,72,100],dtype=float)

# %%
modelo.compile(optimizer = tf.keras.optimizers.Adam(0.1),loss="mean_squared_error")

print("comenzando entrenamiento ...")
historial = modelo.fit(celsius,fahrenheit, epochs=1000, verbose=False)
print("Modelo entrenado")
# Out:
# comenzando entrenamiento ...
# Modelo entrenado

# %%
plt.xlabel(" # Epoca")
plt.ylabel("Magnitud de perdida")
plt.plot(historial.history["loss"])

# %%
print("Hagamos una prediccion")
resultado = modelo.predict([-50.0])
print("El resultado es" + str(resultado)+"farenheit")
# Out:
# Hagamos una prediccion
# 1/1 [==============================] - 0s 82ms/step
# El resultado es[[-57.984066]]farenheit
